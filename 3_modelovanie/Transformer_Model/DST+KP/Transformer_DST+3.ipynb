# %%
import pandas as pd
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns

from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential

from keras.layers import Dense, Activation, Dropout, Input, Conv1D, LSTM, MaxPooling1D, Flatten, TimeDistributed, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Model


from scipy.special import expit, logit

from sklearn.metrics import confusion_matrix, classification_report, matthews_corrcoef
import tensorflow as tf
from tensorflow.keras.layers import Layer, MultiHeadAttention, Dropout, LayerNormalization, Dense
from tensorflow.keras.layers import MultiHeadAttention, Dense, Input, LayerNormalization, Dropout
from tensorflow.keras.models import Model
# Out:
# 2024-05-20 16:45:40.536377: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train = pd.read_csv('train_omni.csv')
test = pd.read_csv('test_omni.csv')
features = ['time1', 'DST', 'DST+3', 'KP']
test = test[features]
train = train[features]
train['time1']=pd.to_datetime(train['time1'])
test['time1']=pd.to_datetime(test['time1'])
predicators = ["DST", "KP"]
y_col='DST+3'
valid_size = int(len(train) * 0.2)
valid = train.iloc[-valid_size:,:].copy()
train = train.iloc[:-valid_size,:].copy()


y_train = train[y_col].values.copy()
X_train = train[predicators].values.copy()
y_val = valid[y_col].values.copy()
X_val = valid[predicators].values.copy()
y_test = test[y_col].values.copy()
X_test = test[predicators].values.copy()

# %%
n_input = 6  
n_features= len(X_train)  
b_size = 256

train_generator = TimeseriesGenerator(X_train, y_train, length=n_input, batch_size=b_size)
val_generator = TimeseriesGenerator(X_val, y_val, length=n_input, batch_size=b_size)
test_generator = TimeseriesGenerator(X_test, y_test, length=n_input, batch_size=256)

# %%
class TransformerEncoderLayer(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, input_dim, rate=0.1, **kwargs):
        super(TransformerEncoderLayer, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.input_dim = input_dim
        self.rate = rate
        self.input_proj = Dense(embed_dim)
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation="relu"),
            Dense(embed_dim)
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training=False):
        inputs_proj = self.input_proj(inputs)
        attn_output = self.att(inputs_proj, inputs_proj)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs_proj + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

    def get_config(self):
        config = super().get_config()
        config.update({
            'embed_dim': self.embed_dim,
            'num_heads': self.num_heads,
            'ff_dim': self.ff_dim,
            'input_dim': self.input_dim,
            'rate': self.rate
        })
        return config

def build_model(input_shape, embed_dim, num_heads, ff_dim, rate=0.1):
    inputs = tf.keras.Input(shape=input_shape)
    x = TransformerEncoderLayer(embed_dim, num_heads, ff_dim, input_shape[-1], rate)(inputs)
    x = Flatten()(x)
    x = Dense(1, activation='linear')(x)
    return tf.keras.Model(inputs=inputs, outputs=x)

model = build_model((6, 2), embed_dim=64, num_heads=2, ff_dim=256)
model.compile(loss='mse', optimizer='adam', metrics=['mae'])
model.summary()
# Out:
# 2024-05-20 16:45:50.408561: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 6, 2)]            0
#
#  transformer_encoder_layer (  (None, 6, 64)            66752
#  TransformerEncoderLayer)
#
#  flatten (Flatten)           (None, 384)               0
#
#  dense_3 (Dense)             (None, 1)                 385
#
# =================================================================
# Total params: 67,137
# Trainable params: 67,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
saved_model = "3h_KP_transform.keras"
checkpoint = ModelCheckpoint(saved_model, monitor='val_mae', verbose=1, save_best_only=True, mode='min')
early = EarlyStopping(monitor="val_mae", mode="min", patience=25)
callbacks_list = [checkpoint, early]

# %%
history = model.fit(train_generator, validation_data=val_generator, epochs=200, verbose=1, callbacks = callbacks_list)
# Out:
# Epoch 1/200
# 896/896 [==============================] - ETA: 0s - loss: 211.1749 - mae: 8.6905
# Epoch 1: val_mae improved from inf to 8.26264, saving model to 3h_KP_transform.keras
# 896/896 [==============================] - 28s 29ms/step - loss: 211.1749 - mae: 8.6905 - val_loss: 244.4149 - val_mae: 8.2626
# Epoch 2/200
# 895/896 [============================>.] - ETA: 0s - loss: 117.0840 - mae: 6.7274
# Epoch 2: val_mae improved from 8.26264 to 7.36546, saving model to 3h_KP_transform.keras
# 896/896 [==============================] - 26s 28ms/step - loss: 117.0699 - mae: 6.7288 - val_loss: 173.8853 - val_mae: 7.3655
# Epoch 3/200
# 896/896 [==============================] - ETA: 0s - loss: 115.9981 - mae: 6.8184
# Epoch 3: val_mae did not improve from 7.36546
# 896/896 [==============================] - 23s 26ms/step - loss: 115.9981 - mae: 6.8184 - val_loss: 186.9449 - val_mae: 7.8496
# Epoch 4/200
# 894/896 [============================>.] - ETA: 0s - loss: 95.6702 - mae: 6.3284
# Epoch 4: val_mae improved from 7.36546 to 7.22172, saving model to 3h_KP_transform.keras
# 896/896 [==============================] -
val_mae did not improve from 6.75698
# 896/896 [==============================] - 22s 25ms/step - loss: 79.8242 - mae: 5.9571 - val_loss: 130.2378 - val_mae: 6.9162
# Epoch 18/200
# 894/896 [============================>.] - ETA: 0s - loss: 78.5100 - mae: 5.9051
# Epoch 18: val_mae did not improve from 6.75698
# 896/896 [==============================] - 22s 24ms/step - loss: 78.6024 - mae: 5.9077 - val_loss: 135.3274 - val_mae: 6.8745
# Epoch 19/200
# 894/896 [============================>.] - ETA: 0s - loss: 81.2512 - mae: 5.9719
# Epoch 19: val_mae did not improve from 6.75698
# 896/896 [==============================] - 23s 25ms/step - loss: 81.1731 - mae: 5.9690 - val_loss: 141.2545 - val_mae: 7.1437
# Epoch 20/200
# 895/896 [============================>.] - ETA: 0s - loss: 80.9739 - mae: 5.9703
# Epoch 20: val_mae improved from 6.75698 to 6.58960, saving model to 3h_KP_transform.keras
# 896/896 [==============================] - 23s 25ms/step - loss: 80.9718 - mae: 5.9701 - val_loss: 116.4641 - val_mae: 6.5896
# Epoch 21/200
# 895/896 [============================>.] - ETA: 0s - loss: 78.6673 - mae: 5.9170
# Epoch 21: val_mae did not improve from 6.58960
# 896/896 [==============================] - 23s 26ms/step - loss: 79.2548 - mae: 5.9281 - val_loss: 148.0254 - val_mae: 7.6523
# Epoch 22/200
# 894/896 [============================>.] - ETA: 0s - loss: 78.2631 - mae: 5.8815
# Epoch 22: val_mae did not improve from 6.58960
# 896/896 [==============================] - 23s 25ms/step - loss: 78.2558 - mae: 5.8813 - val_loss: 118.5534 - val_mae: 6.7567
# Epoch 23/200
# 895/896 [============================>.] - ETA: 0s - loss: 79.4373 - mae: 5.9489
# Epoch 23: val_mae did not improve from 6.58960
# 896/896 [==============================] - 23s 25ms/step - loss: 79.4559 - mae: 5.9505 - val_loss: 127.1292 - val_mae: 6.9514
# Epoch 24/200
# 896/896 [==============================] - ETA: 0s - loss: 77.8058 - mae: 5.9016
# Epoch 24: val_mae improved from 6.58960 to 6.55615, saving model to 3h_KP_transform.keras
# 896/896 [==============================] - 23s 25ms/step - loss: 77.8058 - mae: 5.9016 - val_loss: 109.2039 - val_mae: 6.5562
# Epoch 25/200
# 896/896 [==============================] - ETA: 0s - loss: 76.9031 - mae: 5.8613
# Epoch 25: val_mae did not improve from 6.55615
# 896/896 [==============================] - 22s 24ms/step - loss: 76.9031 - mae: 5.8613 - val_loss: 130.4935 - val_mae: 6.9989
# Epoch 26/200
# 896/896 [==============================] - ETA: 0s - loss: 78.3471 - mae: 5.8884
# Epoch 26: val_mae did not improve from 6.55615
# 896/896 [==============================] - 23s 25ms/step - loss: 78.3471 - mae: 5.8884 - val_loss: 177.9161 - val_mae: 8.1472
# Epoch 27/200
# 894/896 [============================>.] - ETA: 0s - loss: 79.2882 - mae: 5.9065
# Epoch 27: val_mae did not improve from 6.55615
# 896/896 [==============================] - 23s 25ms/step - loss: 79.2625 - mae: 5.9065 - val_loss: 117.1062 - val_mae: 6.7696
# Epoch 28/200
# 894/896 [============================>.] - ETA: 0s - loss: 78.5340 - mae: 5.9104
# Epoch 28: val_mae did not improve from 6.55615
# 896/896 [==============================] - 22s 25ms/step - loss: 78.5177 - mae: 5.9105 - val_loss: 127.8654 - val_mae: 6.7411
# Epoch 29/200
# 895/896 [============================>.] - ETA: 0s - loss: 78.7074 - mae: 5.8957
# Epoch 29: val_mae did not improve from 6.55615
# 896/896 [==============================] - 22s 25ms/step - loss:
200
# 895/896 [============================>.] - ETA: 0s - loss: 72.7204 - mae: 5.7193
# Epoch 74: val_mae did not improve from 6.51649
# 896/896 [==============================] - 22s 25ms/step - loss: 72.6724 - mae: 5.7177 - val_loss: 115.7788 - val_mae: 6.6457
# Epoch 75/200
# 895/896 [============================>.] - ETA: 0s - loss: 73.7004 - mae: 5.7490
# Epoch 75: val_mae did not improve from 6.51649
# 896/896 [==============================] - 23s 26ms/step - loss: 73.7295 - mae: 5.7494 - val_loss: 111.6889 - val_mae: 6.6512
# Epoch 76/200
# 896/896 [==============================] - ETA: 0s - loss: 72.1105 - mae: 5.6937
# Epoch 76: val_mae improved from 6.51649 to 6.51603, saving model to 3h_KP_transform.keras
# 896/896 [==============================] - 23s 25ms/step - loss: 72.1105 - mae: 5.6937 - val_loss: 105.5967 - val_mae: 6.5160
# Epoch 77/200
# 895/896 [============================>.] - ETA: 0s - loss: 72.7804 - mae: 5.7148
# Epoch 77: val_mae did not improve from 6.51603
# 896/896 [==============================] - 22s 25ms/step - loss: 72.7449 - mae: 5.7140 - val_loss: 107.9384 - val_mae: 6.5978
# Epoch 78/200
# 895/896 [============================>.] - ETA: 0s - loss: 72.8409 - mae: 5.7240
# Epoch 78: val_mae did not improve from 6.51603
# 896/896 [==============================] - 22s 25ms/step - loss: 72.8112 - mae: 5.7234 - val_loss: 115.3688 - val_mae: 6.6183
# Epoch 79/200
# 895/896 [============================>.] - ETA: 0s - loss: 72.7121 - mae: 5.7200
# Epoch 79: val_mae did not improve from 6.51603
# 896/896 [==============================] - 21s 24ms/step - loss: 72.7087 - mae: 5.7198 - val_loss: 106.1678 - val_mae: 6.5642
# Epoch 80/200
# 894/896 [============================>.] - ETA: 0s - loss: 75.4573 - mae: 5.8116
# Epoch 80: val_mae improved from 6.51603 to 6.48792, saving model to 3h_KP_transform.keras
# 896/896 [==============================] - 23s 25ms/step - loss: 75.5454 - mae: 5.8134 - val_loss: 106.4670 - val_mae: 6.4879
# Epoch 81/200
# 895/896 [============================>.] - ETA: 0s - loss: 73.7854 - mae: 5.7458
# Epoch 81: val_mae did not improve from 6.48792
# 896/896 [==============================] - 23s 25ms/step - loss: 73.8137 - mae: 5.7476 - val_loss: 112.4734 - val_mae: 6.6041
# Epoch 82/200
# 894/896 [============================>.] - ETA: 0s - loss: 75.3570 - mae: 5.7814
# Epoch 82: val_mae did not improve from 6.48792
# 896/896 [==============================] - 22s 24ms/step - loss: 75.3118 - mae: 5.7809 - val_loss: 123.2476 - val_mae: 6.9644
# Epoch 83/200
# 894/896 [============================>.] - ETA: 0s - loss: 76.1706 - mae: 5.7979
# Epoch 83: val_mae did not improve from 6.48792
# 896/896 [==============================] - 22s 24ms/step - loss: 76.1673 - mae: 5.7978 - val_loss: 113.0905 - val_mae: 6.6044
# Epoch 84/200
# 895/896 [============================>.] - ETA: 0s - loss: 73.7543 - mae: 5.7193
# Epoch 84: val_mae did not improve from 6.48792
# 896/896 [==============================] - 22s 25ms/step - loss: 73.7973 - mae: 5.7217 - val_loss: 108.0112 - val_mae: 6.6276
# Epoch 85/200
# 894/896 [============================>.] - ETA: 0s - loss: 73.3940 - mae: 5.7283
# Epoch 85: val_mae did not improve from 6.48792
# 896/896 [==============================] - 21s 23ms/step - loss: 73.3720 - mae: 5.7278 - val_loss: 115.3815 - val_mae: 6.9524
# Epoch 86/200
# 896/896 [==============================] - ETA: 0s - loss: 74.2056 - mae: 5.7430
# Epoch 86: val_mae did not improve from 6.48792
# 896/896 [==============================] - 22s 24ms/step - loss: 74.2056 - mae: 5.7430 - val_loss: 111.6775 - val_mae: 6.6997
# Epoch 87/200
# 894/896 [============================>.] - ETA: 0s - loss: 75.0287 - mae: 5.7735
# Epoch 87: val_mae did not improve from 6.48792
# 896/896 [==============================] - 22s 24ms/step - loss: 74.9547 - mae: 5.7707 - val_loss: 117.6424 - val_mae: 6.6648
# Epoch 88/200
# 895/896 [============================>.] - ETA: 0s - loss: 73.6900 - mae: 5.7271
# Epoch 88: val_mae did not improve from 6.48792
# 896/896 [==============================] - 21s 24ms/step - loss: 73.6680 - mae: 5.7265 - val_loss: 108.4259 - val_mae: 6.6061
# Epoch 89/200
# 894/896 [============================>.] - ETA: 0s - loss: 73.1538 - mae: 5.7143
# Epoch 89: val_mae did not improve from 6.48792
# 896/896 [==============================] - 22s 24ms/step - loss: 73.1254 - mae: 5.7138 - val_loss: 110.4210 - val_mae: 6.5996
# Epoch 90/200
# 895/896 [============================>.] - ETA: 0s - loss: 72.5011 - mae: 5.7116
# Epoch 90: val_mae did not improve from 6.48792
# 896/896 [==============================] - 22s 24ms/step - loss: 72.4469 - mae: 5.7093 - val_loss: 108.1936 - val_mae: 6.6169
# Epoch 91/200
# 895/896 [============================>.] - ETA: 0s - loss: 77.2617 - mae: 5.8419
# Epoch 91: val_mae did not improve from 6.48792
# 896/896 [==============================] - 21s 24ms/step - loss: 77.2659 - mae: 5.8428 - val_loss: 120.2849 - val_mae: 6.7460
# Epoch 92/200
# 894/896 [============================>.] - ETA: 0s - loss: 73.0019 - mae: 5.7096
# Epoch 92: val_mae did not improve from 6.48792
# 896/896 [==============================] - 20s 22ms/step - loss: 73.0230 - mae: 5.7102 - val_loss: 123.6210 - val_mae: 7.0688
# Epoch 93/200
# 894/896 [============================>.] - ETA: 0s - loss: 71.3712 - mae: 5.6722
# Epoch 93: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 71.4408 - mae: 5.6747 - val_loss: 108.3303 - val_mae: 6.5701
# Epoch 94/200
# 893/896 [============================>.] - ETA: 0s - loss: 73.0450 - mae: 5.7317
# Epoch 94: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 72.9307 - mae: 5.7281 - val_loss: 139.5536 - val_mae: 7.3618
# Epoch 95/200
# 894/896 [============================>.] - ETA: 0s - loss: 72.7876 - mae: 5.7074
# Epoch 95: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 72.7312 - mae: 5.7061 - val_loss: 126.8342 - val_mae: 7.1071
# Epoch 96/200
# 896/896 [==============================] - ETA: 0s - loss: 72.6786 - mae: 5.6973
# Epoch 96: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 72.6786 - mae: 5.6973 - val_loss: 114.7934 - val_mae: 6.9617
# Epoch 97/200
# 895/896 [============================>.] - ETA: 0s - loss: 74.1302 - mae: 5.7637
# Epoch 97: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 74.1821 - mae: 5.7648 - val_loss: 107.1181 - val_mae: 6.5195
# Epoch 98/200
# 896/896 [==============================] - ETA: 0s - loss: 73.1833 - mae: 5.7275
# Epoch 98: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 73.1833 - mae: 5.7275 - val_loss: 118.0322 - val_mae: 7.0270
# Epoch 99/200
# 896/896 [==============================] - ETA: 0s - loss: 72.7679 - mae: 5.6992
# Epoch 99: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 72.7679 - mae: 5.6992 - val_loss: 113.5067 - val_mae: 6.7986
# Epoch 100/200
# 896/896 [==============================] - ETA: 0s - loss: 71.6002 - mae: 5.6787
# Epoch 100: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 71.6002 - mae: 5.6787 - val_loss: 106.5701 - val_mae: 6.5312
# Epoch 101/200
# 894/896 [============================>.] - ETA: 0s - loss: 72.7428 - mae: 5.7261
# Epoch 101: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 72.7748 - mae: 5.7266 - val_loss: 109.5738 - val_mae: 6.7969
# Epoch 102/200
# 895/896 [============================>.] - ETA: 0s - loss: 72.0853 - mae: 5.6955
# Epoch 102: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 72.1032 - mae: 5.6961 - val_loss: 111.2277 - val_mae: 6.7222
# Epoch 103/200
# 896/896 [==============================] - ETA: 0s - loss: 70.9827 - mae: 5.6703
# Epoch 103: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 70.9827 - mae: 5.6703 - val_loss: 120.2412 - val_mae: 7.1173
# Epoch 104/200
# 895/896 [============================>.] - ETA: 0s - loss: 75.4261 - mae: 5.7722
# Epoch 104: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 75.3970 - mae: 5.7716 - val_loss: 111.8148 - val_mae: 6.5934
# Epoch 105/200
# 894/896 [============================>.] - ETA: 0s - loss: 75.0627 - mae: 5.7627
# Epoch 105: val_mae did not improve from 6.48792
# 896/896 [==============================] - 19s 21ms/step - loss: 75.2133 - mae: 5.7655 - val_loss: 114.6646 - val_mae: 6.8434

# %%
model = keras.models.load_model( '3h_KP_transform.keras', custom_objects={'TransformerEncoderLayer': TransformerEncoderLayer})

# %%
y_pred = model.predict(test_generator)
# Out:
# 633/633 [==============================] - 5s 8ms/step

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test[:-6], y_pred.reshape(-1))
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 73.46249296854204

# %%
y_val_pred = model.predict(val_generator)

true_labels_val = np.where(y_val[n_input:] <= -20, 1, 0)  

def calculate_mcc(y_true, y_pred):
    return matthews_corrcoef(y_true, y_pred)

thresholds = np.arange(-10, -40, -0.1)
mcc_scores = []

for thresh in thresholds:
    predictions = np.where(y_val_pred <= thresh, 1, 0)
    mcc = calculate_mcc(true_labels_val, predictions)
    mcc_scores.append(mcc)

best_threshold_mcc = thresholds[np.argmax(mcc_scores)]
best_mcc = max(mcc_scores)

print("Best Threshold for MCC on Validation Set:", best_threshold_mcc)
print("Best MCC on Validation Set:", best_mcc)
best_threshold_mcc_rounded = round(best_threshold_mcc, 1)
# Out:
# 224/224 [==============================] - 2s 9ms/step
# Best Threshold for MCC on Validation Set: -18.699999999999967
# Best MCC on Validation Set: 0.7990977576967617

# %%
y_pred2 = np.where(y_pred <= best_threshold_mcc_rounded, 1, 0)
y_test2 = np.where(y_test[n_input:]  <= -20, 1, 0)

cm = confusion_matrix(y_test2, y_pred2)
print("Confusion matrix: \n" + str(cm))
# Out:
# Confusion matrix:
# [[124449   5538]
#  [  7392  24651]]

# %%
print(classification_report(y_test2, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95    129987
#            1       0.82      0.77      0.79     32043
#
#     accuracy                           0.92    162030
#    macro avg       0.88      0.86      0.87    162030
# weighted avg       0.92      0.92      0.92    162030

# %%
df = pd.DataFrame(data={"time": test['time1'][n_input:],"y_true": y_test[n_input:].reshape(-1) , "y_predict": y_pred.reshape(-1)})

plt.figure()
plt.title('Predicting the change in DST Index')
plt.plot(df['time'],df['y_true'], label='Skutočné hodnoty')
plt.plot(df['time'],df['y_predict'], label='Predikované hodnoty')
plt.legend()
plt.gcf().autofmt_xdate()
plt.grid(True)

# %%
TN, FP, FN, TP = cm.ravel()
ACC = (TP + TN) / (TP + TN + FP + FN)
MCC = matthews_corrcoef(y_test2, y_pred2)
print("ACC={}".format(ACC))
print("MCC={}".format(MCC))
# Out:
# ACC=0.9201999629698204
# MCC=0.7434050748035166
